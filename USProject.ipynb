# %%
from tkinter import *
root=Tk()
root.geometry('1600x800')
root.title("Car Recommender System ")
Label(root, text="••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••",font=("Helvetica", 24), fg="black").grid(row=0,column=0,columnspan=5,padx=(200,0))
Label(root, text="WELCOME TO CAR RECOMMENDER SYSTEM",font=("Verdana", 30),fg="black").grid(row=1,column=0,columnspan=5,padx=(200,0))
Label(root, text="••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••••",font=("Helvetica", 24),fg="black").grid(row=2,column=0,columnspan=5,padx=(200,0),pady=10)


user=StringVar()
Label(root,text="Please Enter Your Name").grid(row=3,column=0,padx=(450,0),pady=10)
Entry(root,selectbackground="blue", textvariable=user).grid(row=3,column=1,padx=(0,10),pady=10)

length=0
height=0
model=0
mileage=0
engine=0


def start():
    
    global length
    global height
    global model
    global mileage
    global engine

    def step_2(user_choice):
        
        global length
        length = user_choice  
        
    def step_3(user_choice):
        
        global height
        height = user_choice  
        
    def step_4(user_choice):
        
        global model
        model = user_choice  
        
    def step_5(user_choice):
        global mileage
        mileage = user_choice
        
    def step_6(user_choice):
        global engine
        engine = user_choice
        
        
    Label(root,text="What is your demand for 'Length'",font=("Verdana", 18),fg="black").grid(row=34,column=0,padx=(300,0),columnspan=8, sticky='W')
    Button(root,text="4000 mm",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_2(4000)).grid(row=34,column=4,pady=2,padx=(0,5),ipadx=10)
    Button(root,text="4500 mm",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_2(4500)).grid(row=34,column=5,pady=2,padx=(0,5),ipadx=10)
    Button(root,text="5000 mm",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_2(5000)).grid(row=34,column=6,pady=2,padx=(0,5),ipadx=10)

    Label(root,text="What is your demand for 'Height'",font=("Verdana", 18),fg="black").grid(row=35,column=0,padx=(300,0),columnspan=8, sticky='W')
    Button(root,text="1500 mm",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_3(1500)).grid(row=35,column=4,pady=2,padx=(0,5),ipadx=10)
    Button(root,text="1600 mm",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_3(1600)).grid(row=35,column=5,pady=2,padx=(0,5),ipadx=10)
    Button(root,text="1800 mm",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_3(1800)).grid(row=35,column=6,pady=2,padx=(0,5),ipadx=10)
    
    Label(root,text="What is your demand for 'Model'",font=("Verdana", 18),fg="black").grid(row=36,column=0,padx=(300,0),columnspan=8, sticky='W')
    Button(root,text="400 Series",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_4(400)).grid(row=36,column=4,pady=2,padx=(0,5),ipadx=10)
    Button(root,text="500 Series",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_4(600)).grid(row=36,column=5,pady=2,padx=(0,5),ipadx=10)
    Button(root,text="600 Series",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_4(600)).grid(row=36,column=6,pady=2,padx=(0,5),ipadx=10)

    Label(root,text="What is your demand for 'Mileage'",font=("Verdana", 18),fg="black").grid(row=37,column=0,padx=(300,0),columnspan=8, sticky='W')
    Button(root,text="18 miles/l",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_5(18)).grid(row=37,column=4,pady=2,padx=(0,5),ipadx=10)
    Button(root,text="25 miles/l",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_5(25)).grid(row=37,column=5,pady=2,padx=(0,5),ipadx=10)
    Button(root,text="30 miles/l",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_5(30)).grid(row=37,column=6,pady=2,padx=(0,5),ipadx=10)

    Label(root,text="What is your demand for 'Engine'",font=("Verdana", 18),fg="black").grid(row=38,column=0,padx=(300,0),columnspan=8, sticky='W')
    Button(root,text="  275 HP ",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_6(275)).grid(row=38,column=4,pady=2,padx=(0,5),ipadx=10)
    Button(root,text="  325 HP ",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_6(325)).grid(row=38,column=5,pady=2,padx=(0,5),ipadx=10)
    Button(root,text="  Any HP ",activeforeground="white",relief=RAISED, activebackground="grey",command=lambda:step_6(0)).grid(row=38,column=6,pady=2,padx=(0,5),ipadx=10)
   

    def show_car():
        
        global length
        global width
        global model
        global mileage
        global engine
    
        
        option=Tk()
        option.geometry('800x200')
        option.title("Car Recommender System")
        
        
        
        if length==4000:
            
            if height ==1500:
                
                if model ==400:
                    
                    if mileage == 18:
                        
                        Label(option,text="There are two cars with this feature \n1.Audi Q7 4.2 TDI Quattro \n2.Nissan 3.4",font=("Verdana", 12),fg="black").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                        Label(option,text="",font=("Verdana", 12),fg="black").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                        
                    if mileage ==25:
                        
                        if engine == 275:
                    
                            Label(option,text="There is one car with these features .",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="Nissan Kicks Facelift",font=("Verdana", 12),fg="black").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                            
                        if engine == 325 or engine ==0:
                            
                            Label(option,text="With these features, we have the following cars",font=("Verdana", 12),fg="black").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="Maruti Suzuki MG Motor \n Hyundai Honda",font=("Verdana", 12),fg="black").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                            
                    if mileage == 30:
                        
                        if engine == 275 or engine ==0:
                            
                            Label(option,text="Here are the recommendations for you:",font=("Verdana", 12),fg="black").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="BMW Audi. Mercedes Benz Skoda. Datsun Mitsubishi",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                                    
                        if engine ==325:
                            
                            Label(option,text="We are out of stock. We don't have any car matching your selected features.",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                            
                if model == 500 or model == 600:
                    
                    Label(option,text="We are out of stock. We don't have any car matching your selected features.",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                    Label(option,text="",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                    
            if height == 1600 or height ==1800:
                
                Label(option,text="We are out of stock. We don't have any car matching your selected features.",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                Label(option,text="",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                
        if length ==4500:
            
            if height == 1500:
                
                if model == 400:
                    
                    if mileage ==18 or mileage ==25:
                        
                        Label(option,text="We are out of stock. We don't have any car matching your selected features.",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                        Label(option,text="",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                        
                    if mileage == 30:
                        
                        if engine == 275:
                            
                            Label(option,text="We are out of stock. We don't have any car matching your selected features.",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                            
                        if engine == 325 or engine ==0:
                            
                            Label(option,text="Here are the recommendations for you:",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="\n Toyota Mahindra\nTata Kia \nJeep Volkswagen",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                 
                if model == 500 or model ==600:
                    
                    Label(option,text="We are out of stock. We don't have any car matching your selected features.",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                    Label(option,text="",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                    
            if height ==1600:
                
                if model == 400:
                    
                    if mileage == 18:
                        
                        Label(option,text="We are out of stock. We don't have any car matching your selected features.",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                        Label(option,text="",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                        
                    if mileage ==25:
                        
                        if engine == 275 or engine == 0:
                            
                            Label(option,text="Here are the recommendations for you:",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="Mercedes Benz Skoda",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                        
                        if engine == 325:
                            
                            Label(option,text="We are out of stock. We don't have any car matching your selected features.",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                        
                    if mileage == 30:
                        
                        if engine == 275 or engine == 0:
                            
                            Label(option,text="Here are the recommendations for you:",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="BMW Audi, Mercedes Benz Skoda, Datsun Mitsubishi",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                        
                        if engine == 325:
                            
                            Label(option,text="Here are the recommendations for you:",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="BMW Audi, Mercedes Benz Skoda",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
        
        if length ==5000:
            
            if model == 400:
                    
                    if mileage ==18 or mileage ==25:
                        
                        Label(option,text="We are out of stock. We don't have any car matching your selected features.",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                        Label(option,text="",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                        
                    if mielage == 30:
                        
                        if engine == 275:
                            
                            Label(option,text="We are out of stock. We don't have any car matching your selected features.",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                            
                        if engine == 325 or engine ==0:
                            
                            Label(option,text="Here are the recommendations for you:",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="BMW Audi, Mercedes Benz Skoda",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                 
            if model == 500 or model ==600:
                
                 
                Label(option,text="We are out of stock. We don't have any car matching your selected features.",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                Label(option,text="",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                
            if height ==1600:
                
                if model == 400:
                    
                    if mileage == 18:
                        
                        Label(option,text="We are out of stock. We don't have any car matching your selected features.",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                        Label(option,text="",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                        
                    if mileage == 25:
                        
                        if engine == 275 or engine == 0:
                            
                            Label(option,text="Here are the recommendations for you:",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="BMW Audi, Mercedes Benz Skoda",font=("Helvetica", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                        
                        if engine == 325:
                            
                            Label(option,text="We are out of stock. We don't have any car matching your selected features.",font=("Helvetica", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="",font=("Verdana", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                        
                    if mileage == 30:
                        
                        if engine == 275 or engine == 0:
                            
                            Label(option,text="Here are the recommendations for you:",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="BMW Audi",font=("Helvetica", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
                        
                        if engine == 325:
                            
                            Label(option,text="Here are the recommendations for you:",font=("Verdana", 12),fg="blue").grid(row=38,column=0,padx=(100,0),columnspan=6, sticky='W')
                            Label(option,text="Mercedes Benz Skoda",font=("Helvetica", 12),fg="blue").grid(row=39,column=0,padx=(100,0),columnspan=6, sticky='W')
        
                
        option.mainloop()    
                        
    Button(root,text=" Show Recommended Cars ",activeforeground="white",relief=GROOVE, activebackground="grey",command=show_car).grid(row=39,column=1,pady=10)

Button(root,text="Proceed",activeforeground="white",relief=GROOVE, activebackground="grey",command=start).grid(row=24,column=1,pady=5)
root.mainloop()
