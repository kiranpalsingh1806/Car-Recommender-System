# %%
import numpy as np
import pandas as pd

car_dim = pd.read_csv('Car_Dimensions.csv')
car_dim.head(10)
# Out:
#    CarID  Dimensions.Height  Dimensions.Length  Dimensions.Width
# 0      1                140                143               202
# 1      2                140                143               202
# 2      3                140                143               202
# 3      4                140                143               202
# 4      5                140                143               202
# 5      6                 91                 17                62
# 6      7                 91                 17                62
# 7      8                201                221               191
# 8      9                201                221               191
# 9     10                147                 96                34

# %%
eng_fuel = pd.read_csv('Engine_Fuel.csv')
eng_fuel.head()
# Out:
#    CarID Engine Information.Driveline  \
# 0      1              All-wheel drive
# 1      2            Front-wheel drive
# 2      3            Front-wheel drive
# 3      4              All-wheel drive
# 4      5              All-wheel drive
#
#                  Engine Information.Engine Type  Engine Information.Hybrid  \
# 0          Audi 3.2L 6 cylinder 250hp 236ft-lbs                       True
# 1  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo                       True
# 2  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo                       True
# 3  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo                       True
# 4  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo                       True
#
#    Engine Information.Number of Forward Gears Engine Information.Transmission  \
# 0                                           6  6 Speed Automatic Select Shift
# 1                                           6  6 Speed Automatic Select Shift
# ...

# %%
model_name = pd.read_csv('CarModelNo_Name.csv')
model_name.head()
# Out:
#    CarID Identification.Classification           Identification.ID  \
# 0      1        Automatic transmission            2009 Audi A3 3.2
# 1      2        Automatic transmission       2009 Audi A3 2.0 T AT
# 2      3           Manual transmission          2009 Audi A3 2.0 T
# 3      4        Automatic transmission  2009 Audi A3 2.0 T Quattro
# 4      5        Automatic transmission  2009 Audi A3 2.0 T Quattro
#
#   Identification.Make
# 0                Audi
# 1                Audi
# 2                Audi
# 3                Audi
# 4                Audi

# %%
eng_dim = pd.merge(eng_fuel, model_name, on='CarID')

# %%
eng_dim.head(4)
# Out:
#    CarID Engine Information.Driveline  \
# 0      1              All-wheel drive
# 1      2            Front-wheel drive
# 2      3            Front-wheel drive
# 3      4              All-wheel drive
#
#                  Engine Information.Engine Type  Engine Information.Hybrid  \
# 0          Audi 3.2L 6 cylinder 250hp 236ft-lbs                       True
# 1  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo                       True
# 2  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo                       True
# 3  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo                       True
#
#    Engine Information.Number of Forward Gears Engine Information.Transmission  \
# 0                                           6  6 Speed Automatic Select Shift
# 1                                           6  6 Speed Automatic Select Shift
# 2                                           6                  6 Speed Manual
# 3                                           6  6 Speed Automatic Select Shift
#
# ...

# %%
eng_dim.groupby('Identification.ID')['Fuel Information.City mpg'].head()
# Out:
# 0       18
# 1       22
# 2       21
# 3       21
# 4       21
#         ..
# 5071    18
# 5072    12
# 5073    12
# 5074    17
# 5075    17
# Name: Fuel Information.City mpg, Length: 5076, dtype: int64
